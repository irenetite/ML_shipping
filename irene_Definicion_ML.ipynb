# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
# opción 1:
titulo_1 = "Viralidad o calidad: combatiendo el clickbait"

# opción 2:
titulo_2 = "Predicción de retrasos en envío y crisis de reputación" # es un churro de título, pero no estaba inspirada

# %% [markdown]
# ### TEMA

# %%
tema_1 = '''OPCIÓN A (Periodismo):
Análisis de Medios. Análisis de la estructura de titulares y metadatos para predecir
su popularidad (shares) y clasificar su nivel de sensacionalismo, equilibrando el tráfico
web con la reputación y credibilidad de la marca'''

tema_2 = '''OPCIÓN B (Logística):
Optimización logística y experiencia del usuario. Análisis de los datos de la cadena de suministro
para predecir entregas tardías, permitiendo tomar medidas proactivas que eviten reseñas negativas
y mejoren la satisfacción del cliente
'''

# %% [markdown]
# ### OBJETIVOS

# %% [markdown]
# Define aquí el objetivo del proyecto

# %%
# Proyecto Periodismo: Tu modelo predecirá un 1 (Viral) o un 0 (No viral)
# leyendo las características del titular.
# Si usas el dataset "Online News Popularity" de Mashable, tu target original
# es la columna llamada shares (el número total de veces que el artículo fue
# compartido en redes sociales).

# Proyecto Logística: Tu modelo predecirá un 1 (Llegará tarde) o un 0
# (Llegará a tiempo) analizando las características del paquete y el almacén
# Si usas el dataset "E-Commerce Shipping Data", el target viene mucho más claro
# y preparado desde el principio. La columna se llama Reached.on.Time_Y.N
# (Llegó a tiempo Sí/No).

# %% [markdown]
# # OPCIÓN A (Clickbait vs. Calidad):
#
# - Desarrollar un modelo de Machine Learning supervisado que prediga si una noticia será viral basándose en características de su titular (longitud, polaridad, palabras clave).
#
# - Implementar al menos un modelo no supervisado para agrupar noticias según su estilo periodístico (ej. informativo, clickbait agresivo, opinión) y detectar saturación temática.
#
# - Desarrollar un workflow completo (limpieza, EDA, feature engineering) que culmine en una app de Streamlit donde un redactor pueda evaluar su titular en tiempo real antes de publicarlo.
#
# # OPCIÓN B (Logística E-commerce):
#
# - Crear un modelo predictivo supervisado que determine si un paquete llegará con retraso antes de salir del almacén, en función del peso, coste, tipo de envío y almacén de origen.
#
# - Utilizar un modelo no supervisado para agrupar las rutas de envío y detectar los cuellos de botella más críticos en la cadena de suministro.
#
# - Demostrar el impacto en negocio mediante una herramienta en Streamlit que alerte a Atención al Cliente para enviar cupones de descuento proactivos antes de que el cliente reclame.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# # OPCIÓN A: Online News Popularity Dataset
# - Origen: UCI Machine Learning Repository / Kaggle (Mashable News)
# - Descripción: Contiene estadísticos de artículos publicados por Mashable en un periodo de dos años. Cumple con el requisito de volumen, superando ampliamente las 1.000 observaciones (tiene cerca de 39.000 registros y 61 variables predictoras).
# # OPCIÓN B: E-Commerce Shipping Data
# - Origen: Kaggle
# - Descripción: Datos pertenecientes a una empresa de envíos internacionales de productos electrónicos. Contiene variables como el bloque del almacén, modo de envío, descuento ofrecido, peso y valoración previa del cliente. Cuenta con más de 10.000 observaciones.

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
# df_1.head()

# %%
# Siguiente dataset...
# df_2.head()
